# %% [markdown]
# ## Import de tensorflow

# %%
import tensorflow as tf
import numpy as np

# %% [markdown]
# ## Descarga del modelo

# %%
import gdown
id= '1_zkVtIRrxIsSq9nsGllHVoySG9_PS3lK'
output = "/content/doggos_model"
gdown.download_folder(id=id, output=output)
# Out:
# Retrieving folder list
# Retrieving folder 1-G_yMk5OeS1ljeMzwMmGErK4IYxMs4n2 assets
# Processing file 1-30kByD_YZLHgJuHMEzb2ZqInl05YUrn keras_metadata.pb
# Processing file 1-4Tycf6Scdg-Lzwzozwcv5dE5iwsXpX6 saved_model.pb
# Retrieving folder 1-H6AZ1mGYQHPxMpBYN157TNOZtMhWJk6 variables
# Processing file 1-KmafAB7o-eV6MXpzuwQDMG144n3gGwm variables.data-00000-of-00001
# Processing file 1-J4q3pI4LMxpCDLPiQjDZJ42xk4HsyoB variables.index
# Building directory structure completed
# Retrieving folder list completed
# Building directory structure
# Downloading...
# From: https://drive.google.com/uc?id=1-30kByD_YZLHgJuHMEzb2ZqInl05YUrn
# To: /content/doggos_model/keras_metadata.pb
# 100%|██████████| 19.9k/19.9k [00:00<00:00, 12.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-4Tycf6Scdg-Lzwzozwcv5dE5iwsXpX6
# To: /content/doggos_model/saved_model.pb
# 100%|██████████| 168k/168k [00:00<00:00, 39.5MB/s]
# Downloading...
# ...

# %% [markdown]
# ## Carga del Modelo

# %%
model = tf.keras.models.load_model('/content/doggos_model')

# %% [markdown]
# ## Carga tu fotografia

# %%
from google.colab import files
dog_img = files.upload()
# Out:
#      <input type="file" id="files-2f44dcbd-3bc8-433f-8f18-332b39b2476f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f44dcbd-3bc8-433f-8f18-332b39b2476f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Mira que estado de animo tiene tu perro!

# %%
class_names = ['Enojado', 'Feliz', 'Relajado', 'Triste'] 
img_array = tf.keras.utils.img_to_array(dog_img)
img_array = tf.expand_dims(img_array, 0) 

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "Tu Perro esta {} con un {:.2f}% de seguridad."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
